# %% [markdown]
# # Router Query Engine
#
# In this notebook we will look into `RouterQueryEngine` to route the user queries to one of the available query engine tools. These tools can be different indicies/ query engine on same documents/ different documents.

# %% [markdown]
# ## Installation

# %%
# !pip install llama-index -q
# !pip install llama-index-llms-anthropic -q
# !pip install llama-index-embeddings-huggingface -q

# %% [markdown]
# ## Setup Logging

# %%
# NOTE: This is ONLY necessary in jupyter notebook.
# Details: Jupyter runs an event-loop behind the scenes.
#          This results in nested event-loops when we start an event-loop to make async queries.
#          This is normally not allowed, we use nest_asyncio to allow it for convenience.
import nest_asyncio

nest_asyncio.apply()

import logging
import sys

# Set up the root logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)  # Set logger level to INFO

# Clear out any existing handlers
logger.handlers = []

# Set up the StreamHandler to output to sys.stdout (Colab's output)
handler = logging.StreamHandler(sys.stdout)
handler.setLevel(logging.INFO)  # Set handler level to INFO

# Add the handler to the logger
logger.addHandler(handler)

from IPython.display import display, HTML

# %% [markdown]
# ## Set Anthropic API Key

# %%
import os

os.environ["ANTHROPIC_API_KEY"] = "YOUR ANTHROPIC API KEY"

# %% [markdown]
# ## Set LLM and Embedding model
#
# We will use anthropic latest released `Claude 3 Opus` models.

# %%
from llama_index.llms.anthropic import Anthropic
from llama_index.embeddings.huggingface import (
    HuggingFaceEmbedding,
)  # since Anthropic doesn't provide embedding models
# Out:
# NumExpr defaulting to 2 threads.

# %%
llm = Anthropic(temperature=0.0, model="claude-3-opus-20240229")
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-base-en-v1.5")

# %%
from llama_index.core import Settings

Settings.llm = llm
Settings.embed_model = embed_model
Settings.chunk_size = 512

# %% [markdown]
# ## Download Document

# %%
# !mkdir -p 'data/paul_graham/'
# !wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/examples/data/paul_graham/paul_graham_essay.txt' -O 'data/paul_graham/paul_graham_essay.txt'
# Out:
# --2024-03-13 07:13:16--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/examples/data/paul_graham/paul_graham_essay.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75042 (73K) [text/plain]
# Saving to: ‘data/paul_graham/paul_graham_essay.txt’
#
# data/paul_graham/pa 100%[===================>]  73.28K  --.-KB/s    in 0.04s
#
# 2024-03-13 07:13:16 (1.62 MB/s) - ‘data/paul_graham/paul_graham_essay.txt’ saved [75042/75042]

# %% [markdown]
# ## Load Document

# %%
# Load documents
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader("data/paul_graham").load_data()

# %% [markdown]
# ## Create Indicies and Query Engines

# %%
from llama_index.core import SummaryIndex, VectorStoreIndex

# Summary Index for summarization questions
summary_index = SummaryIndex.from_documents(documents)

# Vector Index for answering specific context questions
vector_index = VectorStoreIndex.from_documents(documents)

# %%
# Summary Index Query Engine
summary_query_engine = summary_index.as_query_engine(
    response_mode="tree_summarize",
    use_async=True,
)

# Vector Index Query Engine
vector_query_engine = vector_index.as_query_engine()

# %% [markdown]
# ## Creat tools for summary and vector query engines

# %%
from llama_index.core.tools.query_engine import QueryEngineTool

# Summary Index tool
summary_tool = QueryEngineTool.from_defaults(
    query_engine=summary_query_engine,
    description="Useful for summarization questions related to Paul Graham eassy on What I Worked On.",
)

# Vector Index tool
vector_tool = QueryEngineTool.from_defaults(
    query_engine=vector_query_engine,
    description="Useful for retrieving specific context from Paul Graham essay on What I Worked On.",
)

# %% [markdown]
# ## Create Router Query Engine

# %%
from llama_index.core.query_engine.router_query_engine import RouterQueryEngine
from llama_index.core.selectors.llm_selectors import LLMSingleSelector, LLMMultiSelector

# %%
# Create Router Query Engine
query_engine = RouterQueryEngine(
    selector=LLMSingleSelector.from_defaults(),
    query_engine_tools=[
        summary_tool,
        vector_tool,
    ],
)

# %% [markdown]
# ## Test Queries

# %%
response = query_engine.query("What is the summary of the document?")
# Out:
# HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# Selecting query engine 0: The question is asking for a summary of the document. Choice 1 specifically mentions that it is useful for summarization questions related to Paul Graham's essay on What I Worked On, making it the most relevant choice for answering the given question..
# HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"

# %%
display(HTML(f'<p style="font-size:20px">{response.response}</p>'))
# Out:
# <p style="font-size:20px">The document is an autobiographical essay by Paul Graham about the major projects and interests he has worked on throughout his life. The key points are:
#
# - As a child and teenager, he was interested in writing and programming. He wrote short stories and tried programming on an IBM 1401 and later microcomputers.
#
# - In college he studied philosophy and then switched to AI. He became disillusioned with AI as it was practiced at the time.
#
# - After college he attended art school, first at RISD and then in Florence. He became very interested in painting, especially still lifes.
#
# - In 1995, he and Robert Morris started Viaweb, one of the first web application companies. They pioneered many concepts like web-based software. Yahoo acquired Viaweb in 1998.
#
# - In 2005, he co-founded Y Combinator, a new kind of startup investment firm, with Jessica Livingston, Robert Morris and Trevor Blackwell. YC funded startups in batches and worked closely with the founders. It was very successful and influential.
#
# - He started the website Hacker News and wrote many essays which he published online. This was an early example of using the web as the primary medium for publishing writing.
#
# - From 2015-2019 he worked on a new Lisp programming language called Bel.
#
# - Throughout his life he alternated between focusing intensely on technology projects like Viaweb, Y Combinator and Bel, and creative pursuits like painting and essay writing. The essay chronicles how his interests and focus evolved over time.</p>

# %%
response = query_engine.query("What did Paul Graham do growing up?")
# Out:
# HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# Retrying request to /v1/messages in 0.885283 seconds
# HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# Retrying request to /v1/messages in 1.641576 seconds
# HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# Retrying request to /v1/messages in 3.345043 seconds
# HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# Selecting query engine 1: The question asks about specific details from Paul Graham's life, which would likely be found in the original essay. A summary of the essay may not include all the relevant details about what he did growing up..
# HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"

# %%
display(HTML(f'<p style="font-size:20px">{response.response}</p>'))
# Out:
# <p style="font-size:20px">According to the essay, the two main things Paul Graham worked on outside of school before college were writing and programming. He wrote short stories, which he admits were awful, with hardly any plot and just characters with strong feelings. He also tried writing some of his first programs on an IBM 1401 computer in the basement of his junior high school, using an early version of Fortran. However, he had difficulty figuring out what to do with the 1401 since the only input was data stored on punched cards, which he didn't have.</p>
